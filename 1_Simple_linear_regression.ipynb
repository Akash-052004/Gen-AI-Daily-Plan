# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-052004/Gen-AI-Daily-Plan/blob/main/1_Simple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Simple linear regression

from sklearn.linear_model import LinearRegression
import numpy as np

#dep
X = np.array([[1], [2], [3], [4], [5]])
#in_dep
y = np.array([2, 4, 6, 8, 10])


model = LinearRegression()
model.fit(X, y)

prediction = model.predict([[6]])

print(prediction[0])
print(model.coef_[0]) #coefficient m | y = mx+c
print(model.intercept_) #intercept c
# Out:
# 12.0
# 2.0
# 0.0
